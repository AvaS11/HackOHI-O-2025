# %%
# Merging Data from lines and flows

# Pandas
import pandas as pd

# Read CSV files
lines = pd.read_csv('lines.csv')
flows = pd.read_csv('line_flows_nominal.csv')

# Merge DataFrames on 'name' column
df = lines.merge(flows, on='name')
df['loading_percent'] = df['p0_nominal'] / df['s_nom'] * 100

# Display the first few rows of the merged DataFrame
df.head()
# Out:
#   name  bus0  bus1  ckt                                branch_name bus0_name  \
# 0   L0     1     5    1    ALOHA138 (1)  TO  HONOLULU138 (5) CKT 1  ALOHA138
# 1   L1     1     5    2    ALOHA138 (1)  TO  HONOLULU138 (5) CKT 2  ALOHA138
# 2   L2     1    22    1    ALOHA138 (1)  TO  WAIPAHU138 (22) CKT 1  ALOHA138
# 3   L3     1    25    1  ALOHA138 (1)  TO  EWA BEACH138 (25) CKT 1  ALOHA138
# 4   L4     1    25    2  ALOHA138 (1)  TO  EWA BEACH138 (25) CKT 2  ALOHA138
#
#       bus1_name         x         r         b  s_nom             conductor  \
# 0   HONOLULU138  3.982672  0.647496  0.000044    228   795 ACSR 26/7 DRAKE
# 1   HONOLULU138  3.982672  0.647496  0.000044    228   795 ACSR 26/7 DRAKE
# 2    WAIPAHU138  4.603506  0.712246  0.000032    172  556.5 ACSR 26/7 DOVE
# 3  EWA BEACH138  3.008571  0.550372  0.000040    215   795 ACSR 26/7 DRAKE
# 4  EWA BEACH138  3.008571  0.550372  0.000040    215   795 ACSR 26/7 DRAKE
#
#    MOT  v_ang_min  v_ang_max  status  original_index  p0_nominal  \
# 0   80        0.0        0.0     1.0               3   79.168558
# 1   80        0.0        0.0     1.0               4   79.168558
# 2   75        0.0        0.0     1.0               5   22.449716
# 3   85        0.0        0.0     1.0               6   66.694086
# 4   85        0.0        0.0     1.0               7   66.694086
#
#    loading_percent
# 0        34.723052
# 1        34.723052
# 2        13.052160
# 3        31.020505
# 4        31.020505

# %%
df['loading_percent'].describe()
# Out:
# count    77.000000
# mean     39.147089
# std      21.667443
# min       0.681751
# 25%      24.425458
# 50%      39.602312
# 75%      56.159315
# max      80.763285
# Name: loading_percent, dtype: float64

# %%
df.sort_values('loading_percent', ascending=False).head(10)
# Out:
#    name  bus0  bus1  ckt                                  branch_name  \
# 49  L49    19    23    2  PEARL CITY69 (19)  TO  WAIPAHU69 (23) CKT 2
# 48  L48    19    23    1  PEARL CITY69 (19)  TO  WAIPAHU69 (23) CKT 1
# 51  L51    19    23    4  PEARL CITY69 (19)  TO  WAIPAHU69 (23) CKT 4
# 50  L50    19    23    3  PEARL CITY69 (19)  TO  WAIPAHU69 (23) CKT 3
# 67  L67    27    29    1         KAHUKU69 (27)  TO  LAIE69 (29) CKT 1
# 21  L21     3    19    2    FLOWER69 (3)  TO  PEARL CITY69 (19) CKT 2
# 22  L22     3    19    3    FLOWER69 (3)  TO  PEARL CITY69 (19) CKT 3
# 20  L20     3    19    1    FLOWER69 (3)  TO  PEARL CITY69 (19) CKT 1
# 46  L46    16    18    1        PALM69 (16)  TO  VOLCANO69 (18) CKT 1
# 35  L35     7    13    2         SURF69 (7)  TO  COCONUT69 (13) CKT 2
#
#        bus0_name     bus1_name         x         r         b  s_nom  \
# 49  PEARL CITY69     WAIPAHU69  1.449677  0.598934  0.000028     96
# 48  PEARL CITY69     WAIPAHU69  1.449677  0.598934  0.000028     96
# 51  PEARL CITY69     WAIPAHU69  1.449677  0.598934  0.000028     96
# 50  PEARL CITY69     WAIPAHU69  1.449677  0.598934  0.000028     96
# 67      KAHUKU69        LAIE69  2.039232  1.136927  0.000027     70
# 21      FLOWER69  PEARL CITY69  1.486813  0.657970  0.000114     86
# 22      FLOWER69  PEARL CITY69  1.486813  0.657970  0.000114     86
# 20      FLOWER69  PEARL CITY69  1.486813  0.657970  0.000114     86
# 46        PALM69     VOLCANO69  1.867645  0.739383  0.000040     45
# 35        SURF69     COCONUT69  1.319083  0.448010  0.000020     40
#
#                  conductor  MOT  v_ang_min  v_ang_max  status  original_index  \
# 49    556.5 ACSR 26/7 DOVE   85        0.0        0.0     1.0              56
# 48    556.5 ACSR 26/7 DOVE   85        0.0        0.0     1.0              55
# 51    556.5 ACSR 26/7 DOVE   85        0.0        0.0     1.0              58
# 50    556.5 ACSR 26/7 DOVE   85        0.0        0.0     1.0              57
# 67  336.4 ACSR 30/7 ORIOLE   85        0.0        0.0     1.0              79
# 21    556.5 ACSR 26/7 DOVE   75        0.0        0.0     1.0              24
# 22    556.5 ACSR 26/7 DOVE   75        0.0        0.0     1.0              25
# 20    556.5 ACSR 26/7 DOVE   75        0.0        0.0     1.0              23
# 46    4/0 ACSR 6/1 PENGUIN   85        0.0        0.0     1.0              53
# 35     3/0 ACSR 6/1 PIGEON   85        0.0        0.0     1.0              39
#
#     p0_nominal  loading_percent
# 49   77.532753        80.763285
# 48   77.532753        80.763285
# 51   77.532753        80.763285
# 50   77.532753        80.763285
# 67   53.650000        76.642857
# 21   62.562275        72.746832
# 22   62.562275        72.746832
# 20   62.562275        72.746832
# 46   29.918636        66.485858
# 35   24.721468        61.803671

# %%
# More EDA
df.groupby('conductor')['loading_percent'].mean().sort_values()
df['MOT'].value_counts()
df['MOT'].hist()
# Out:
# <Axes: >

# %%
lines_geo = gpd.read_file('oneline_lines.geojson')
lines_geo.columns
# Out:
# Index(['LineName', 'PWObjectType', 'BusNumFrom', 'BusNumTo', 'Circuit',
#        'BusNameTo', 'BusNameFrom', 'nomkv', 'Name', 'geometry'],
#       dtype='object')

# %%
import geopandas as gpd

# Load the geojson
lines_geo = gpd.read_file('oneline_lines.geojson')

# Merge with your main DataFrame (df) using the matching line name
geo_df = lines_geo.merge(df, left_on='Name', right_on='name')

# Plot line loading percentages on the map
geo_df.plot(column='loading_percent', legend=True, cmap='coolwarm')
# Out:
# <Axes: >
